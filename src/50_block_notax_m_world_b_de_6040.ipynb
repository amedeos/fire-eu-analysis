# %% [markdown]
# # Safe Withdrawal Rate Analysis: MSCI World 60% + Bund 10Y 40% (No Tax)
#
# ## Overview
#
# This notebook performs a **Monte Carlo simulation** using **block bootstrap** methodology to analyze the **Safe Withdrawal Rate (SWR)** for a portfolio composed of:
# - **60% MSCI World Index (Net Total Return)** (global equities)
# - **40% German Bund 10Y** (government bonds)
#
# > ⚠️ **Tax Assumption**: This simulation assumes **no capital gains tax** is applied on withdrawals. This represents an idealized scenario (e.g., tax-advantaged accounts, jurisdictions with no capital gains tax, or assets held beyond tax-exemption thresholds). For a realistic analysis in taxed environments, withdrawal amounts should be grossed up to account for applicable taxes.
#
# ## Methodology
#
# ### Block Bootstrap Approach
# Unlike traditional Monte Carlo simulations that assume independent returns, the **block bootstrap** preserves the temporal structure and correlations in financial data by:
# 1. Sampling **consecutive blocks** of historical data (default: 6 months)
# 2. Randomly concatenating these blocks to create simulated future scenarios
# 3. Maintaining serial correlation and regime persistence
#
# ### Key Features
# - **Historical data**: Daily returns from 2000-2025 (MSCI World) and 1997-2025 (Bund)
# - **Inflation adjustment**: Withdrawals adjusted using Euro area HICP inflation
# - **Calendar days**: All calculations use 365 days/year (not trading days)
# - **100,000 simulations**: Provides robust statistical estimates
# - **30-year horizon**: Standard retirement planning period
# - **No capital gains tax**: Withdrawals are not subject to any taxation
#
# ### What This Analysis Provides
# 1. **Success rate**: Probability that portfolio survives 30 years
# 2. **Portfolio evolution**: Percentile bands (5th, 25th, 50th, 75th, 95th)
# 3. **Sensitivity analysis**: Impact of different withdrawal rates (2%-5%)
# 4. **Failure analysis**: Distribution of depletion years for failed scenarios
#
# ### Data Sources
# - **Equities**: MSCI World Net Total Return Index (EUR) - includes reinvested dividends net of withholding taxes
# - **Bonds**: German Bund 10Y yields (converted to returns)
# - **Inflation**: Eurostat HICP for Euro area
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from typing import Tuple, List, Dict
from datetime import datetime
from joblib import Parallel, delayed

# Visualization settings
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')
# %matplotlib inline

# %% [markdown]
# ---
#
# ## 1. Data Loading Functions
#
# These functions load historical price data for:
# - **Equity indices**: MSCI World (Net Total Return), MSCI ACWI, MSCI Italy, STOXX Europe 600
# - **Bond yields**: BTP 10Y (Italy), Bund 10Y (Germany), OAT 10Y (France)
# - **Inflation**: ISTAT FOI (Italy), Eurostat HICP (Italy & Euro area)
#
# > **Note on MSCI indices**: All MSCI indices used are **Net Total Return** versions, which include reinvested dividends after deducting withholding taxes applicable to non-resident investors.

# %%
def load_asset_data(base_path: Path) -> Dict[str, pd.DataFrame]:
    """
    Load all asset data from CSV files.
    
    Returns:
        Dictionary with asset names as keys and DataFrames as values
    """
    assets = {}
    
    # MSCI indices
    msci_files = {
        'MSCI_WORLD': 'data/msci/WORLD.csv',
        'MSCI_ACWI': 'data/msci/ACWI.csv',
        'MSCI_ITALY': 'data/msci/ITALY.csv'
    }
    
    for name, path in msci_files.items():
        df = pd.read_csv(base_path / path)
        df.columns = ['date', 'price']
        df['date'] = pd.to_datetime(df['date'])
        df = df.sort_values('date')
        assets[name] = df
    
    # STOXX
    df_stoxx = pd.read_csv(base_path / 'data/stoxx/STOXX_SXXGR_DAILY.csv')
    df_stoxx.columns = ['date', 'price']
    df_stoxx['date'] = pd.to_datetime(df_stoxx['date'])
    df_stoxx = df_stoxx.sort_values('date')
    assets['STOXX_SXXGR'] = df_stoxx
    
    # BTP 10Y (Italian bonds)
    df_btp = pd.read_csv(base_path / 'data/bdi/BMK0200/MFN_BMK.D.020.922.0.EUR.210.csv')
    df_btp.columns = ['date', 'yield']
    df_btp['date'] = pd.to_datetime(df_btp['date'])
    df_btp = df_btp.sort_values('date')
    assets['BTP_10Y'] = df_btp
    
    # Bund 10Y (German bonds)
    df_bund = pd.read_csv(base_path / 'data/bund/bbsis/BBSIS_10_YEARS_YIELDS.csv')
    df_bund.columns = ['date', 'yield']
    df_bund['date'] = pd.to_datetime(df_bund['date'])
    df_bund = df_bund.sort_values('date')
    assets['BUND_10Y'] = df_bund
    
    # OAT 10Y (French bonds)
    df_oat = pd.read_csv(base_path / 'data/oat/FRANCE_10_YEARS_DAILY_YIELDS_MERGED_FR10.csv')
    df_oat.columns = ['date', 'yield']
    df_oat['date'] = pd.to_datetime(df_oat['date'])
    df_oat = df_oat.sort_values('date')
    assets['OAT_10Y'] = df_oat
    
    return assets


def load_inflation_data(base_path: Path) -> Dict[str, pd.DataFrame]:
    """
    Load inflation data from CSV files.
    
    Returns:
        Dictionary with inflation series names as keys and DataFrames as values
    """
    inflation = {}
    
    # ISTAT FOI (Italy)
    df_foi = pd.read_csv(base_path / 'data/istat/FOI_MONTHLY.csv')
    df_foi.columns = ['date', 'value', 'base']
    df_foi['date'] = pd.to_datetime(df_foi['date'])
    df_foi = df_foi.sort_values('date')
    inflation['FOI_IT'] = df_foi[['date', 'value']]
    
    # Eurostat HICP
    df_hicp = pd.read_csv(base_path / 'data/eurostat/hicp_it_eu.csv')
    df_hicp['TIME_PERIOD'] = pd.to_datetime(df_hicp['TIME_PERIOD'])
    
    # Filter for Italy and EU
    df_hicp_it = df_hicp[df_hicp['geo'] == 'Italy'][['TIME_PERIOD', 'OBS_VALUE']].copy()
    df_hicp_it.columns = ['date', 'value']
    df_hicp_it = df_hicp_it.sort_values('date')
    inflation['HICP_IT'] = df_hicp_it
    
    df_hicp_eu = df_hicp[df_hicp['geo'] == 'Euro area (EA11-1999, EA12-2001, EA13-2007, EA15-2008, EA16-2009, EA17-2011, EA18-2014, EA19-2015, EA20-2023)'][['TIME_PERIOD', 'OBS_VALUE']].copy()
    df_hicp_eu.columns = ['date', 'value']
    df_hicp_eu = df_hicp_eu.sort_values('date')
    inflation['HICP_EU'] = df_hicp_eu
    
    return inflation

# %% [markdown]
# ---
#
# ## 2. Data Preparation Functions
#
# ### Return Calculations
# - **Equity returns**: Log returns calculated as `ln(P_t / P_{t-1})`
# - **Bond returns**: Simplified as `yield / 365` (income return only, ignoring duration effects)
# - **Inflation**: Month-over-month percentage change, then converted to daily
#
# ### Key Notes
# - All data uses **calendar days** (365 days/year), not trading days (252 days/year)
# - Monthly inflation is divided by actual days in month for precision
# - Forward-fill is used to handle missing data (weekends, holidays)

# %%
def calculate_daily_returns(df: pd.DataFrame, price_col: str = 'price') -> pd.DataFrame:
    """
    Calculate daily log returns from price data.
    """
    df = df.copy()
    df['return'] = np.log(df[price_col] / df[price_col].shift(1))
    return df.dropna()


def calculate_bond_returns(df: pd.DataFrame, yield_col: str = 'yield') -> pd.DataFrame:
    """
    Calculate daily returns from bond yields using simple approximation.
    Daily return ≈ yield/365 - duration * Δyield
    Simplified: just use yield/365 for income return
    """
    df = df.copy()
    df['return'] = df[yield_col] / 100 / 365  # Simple daily yield return (calendar days)
    return df


def calculate_inflation_rate(df: pd.DataFrame, value_col: str = 'value') -> pd.DataFrame:
    """
    Calculate monthly inflation rate from price index.
    """
    df = df.copy()
    df['inflation'] = (df[value_col] / df[value_col].shift(1) - 1)
    return df.dropna()


def merge_to_common_dates(assets_dict: Dict[str, pd.DataFrame]) -> pd.DataFrame:
    """
    Merge all asset returns to common dates.
    """
    merged = None
    
    for name, df in assets_dict.items():
        df_temp = df[['date', 'return']].copy()
        df_temp.columns = ['date', name]
        
        if merged is None:
            merged = df_temp
        else:
            merged = pd.merge(merged, df_temp, on='date', how='outer')
    
    merged = merged.sort_values('date')
    return merged


def upsample_inflation_to_daily(inflation_df: pd.DataFrame, start_date: str, end_date: str) -> pd.DataFrame:
    """
    Convert monthly inflation to daily by dividing by days in month.
    """
    daily_dates = pd.date_range(start=start_date, end=end_date, freq='D')
    daily_df = pd.DataFrame({'date': daily_dates})
    
    # Create year-month column for merging
    daily_df['year_month'] = daily_df['date'].dt.to_period('M')
    daily_df['days_in_month'] = daily_df['date'].dt.days_in_month
    
    inflation_df = inflation_df.copy()
    inflation_df['year_month'] = inflation_df['date'].dt.to_period('M')
    
    # Merge
    merged = pd.merge(daily_df, inflation_df[['year_month', 'inflation']], 
                      on='year_month', how='left')
    
    # Convert monthly to daily (divide by actual days in month)
    merged['daily_inflation'] = merged['inflation'] / merged['days_in_month']
    merged = merged[['date', 'daily_inflation']]
    merged.columns = ['date', 'inflation']
    
    return merged

# %% [markdown]
# ---
#
# ## 3. Block Bootstrap Implementation
#
# ### Why Block Bootstrap?
# Financial returns exhibit:
# - **Volatility clustering**: High/low volatility periods persist
# - **Serial correlation**: Today's return affects tomorrow's
# - **Market regimes**: Bull/bear markets last for extended periods
#
# ### How It Works
# 1. Divide historical data into overlapping blocks (default: 6 months = ~180 days)
# 2. Randomly sample blocks with replacement
# 3. Concatenate to create 30 years (10,950 days) of simulated returns
# 4. Preserve within-block correlations and patterns
#
# ### Block Size Parameter
# - **Smaller blocks** (1-3 months): More independent, less structure preservation
# - **Larger blocks** (6-12 months): Better structure preservation, less variation
# - **Default**: 6 months balances both objectives

# %%
def block_bootstrap_sample(
    data: pd.DataFrame,
    block_size_months: int = 6,
    n_years: int = 30
) -> pd.DataFrame:
    """
    Generate a block bootstrap sample from historical data.
    
    Args:
        data: DataFrame with date index and return columns
        block_size_months: Size of each block in months
        n_years: Number of years to generate
    
    Returns:
        DataFrame with bootstrapped returns
    """
    block_size_days = block_size_months * 30  # Approximate calendar days per month
    n_days_needed = n_years * 365  # Calendar days per year
    
    # Adjust block size if data is not long enough
    max_block_size = len(data) - 1
    if block_size_days > max_block_size:
        original_block_size = block_size_days
        block_size_days = max(30, max_block_size // 2)  # At least 1 month
        print(f"  Warning: Reducing block size from {original_block_size} to {block_size_days} days due to limited data")
    
    n_blocks_needed = int(np.ceil(n_days_needed / block_size_days))
    
    # Ensure we have enough data
    n_possible_blocks = len(data) - block_size_days + 1
    
    if n_possible_blocks < 1:
        raise ValueError(
            f"Not enough data for block size {block_size_days} days. "
            f"Available data: {len(data)} days. "
            f"Need at least {block_size_days} days."
        )
    
    # Randomly select block start positions
    block_starts = np.random.randint(0, n_possible_blocks, size=n_blocks_needed)
    
    # Concatenate blocks
    samples = []
    for start in block_starts:
        block = data.iloc[start:start + block_size_days].copy()
        samples.append(block)
    
    result = pd.concat(samples, ignore_index=True)
    
    # Trim to exact length needed
    result = result.iloc[:n_days_needed]
    
    # Reset index to be sequential days
    result = result.reset_index(drop=True)
    
    return result

# %% [markdown]
# ---
#
# ## 4. Load Historical Data
#
# Loading all available asset classes and inflation data from CSV files.

# %%
# Set base path
BASE_PATH = Path('..')

# Load data
print("Loading asset data...")
assets = load_asset_data(BASE_PATH)

print("Loading inflation data...")
inflation_data = load_inflation_data(BASE_PATH)

# Show available assets
print("\nAvailable assets:")
for name, df in assets.items():
    print(f"  {name}: {len(df)} observations from {df['date'].min()} to {df['date'].max()}")

print("\nAvailable inflation series:")
for name, df in inflation_data.items():
    print(f"  {name}: {len(df)} observations from {df['date'].min()} to {df['date'].max()}")
# Out:
# Loading asset data...
# Loading inflation data...
#
# Available assets:
#   MSCI_WORLD: 9106 observations from 2000-12-29 00:00:00 to 2025-12-03 00:00:00
#   MSCI_ACWI: 9106 observations from 2000-12-29 00:00:00 to 2025-12-03 00:00:00
#   MSCI_ITALY: 9106 observations from 2000-12-29 00:00:00 to 2025-12-03 00:00:00
#   STOXX_SXXGR: 9991 observations from 1986-12-31 00:00:00 to 2025-12-12 00:00:00
#   BTP_10Y: 11263 observations from 1994-12-31 00:00:00 to 2025-10-31 00:00:00
#   BUND_10Y: 10354 observations from 1997-08-01 00:00:00 to 2025-12-05 00:00:00
#   OAT_10Y: 9441 observations from 2000-01-31 00:00:00 to 2025-12-05 00:00:00
#
# Available inflation series:
#   FOI_IT: 358 observations from 1996-01-01 00:00:00 to 2025-10-01 00:00:00
#   HICP_IT: 358 observations from 1996-01-01 00:00:00 to 2025-10-01 00:00:00
#   HICP_EU: 358 observations from 1996-01-01 00:00:00 to 2025-10-01 00:00:00

# %% [markdown]
# ### Calculate Daily Returns
#
# Converting price/yield data into daily return series.

# %%
# Calculate returns for each asset
print("Calculating returns...")

assets_returns = {}

# Equity indices
for name in ['MSCI_WORLD', 'MSCI_ACWI', 'MSCI_ITALY', 'STOXX_SXXGR']:
    assets_returns[name] = calculate_daily_returns(assets[name])

# Bond yields (convert to returns)
for name in ['BTP_10Y', 'BUND_10Y', 'OAT_10Y']:
    assets_returns[name] = calculate_bond_returns(assets[name])

# Calculate inflation rates
inflation_returns = {}
for name, df in inflation_data.items():
    inflation_returns[name] = calculate_inflation_rate(df)

print("Done!")
# Out:
# Calculating returns...
# Done!

# %% [markdown]
# ---
#
# ## 5. Portfolio Configuration
#
# ### Portfolio Allocation
# - **60% MSCI World (Net Total Return)**: Global equity exposure across developed markets, dividends reinvested net of withholding taxes
# - **40% Bund 10Y**: German government bonds (safe haven asset)
#
# ### Simulation Parameters
# - **Initial portfolio**: €1,000,000
# - **Withdrawal rate**: 4% annually (inflation-adjusted)
# - **Retirement horizon**: 30 years
# - **Block size**: 6 months (~180 calendar days)
# - **Simulations**: 100,000 runs
# - **Inflation**: Euro area HICP
#
# ### Tax Assumptions
# - **No capital gains tax**: Withdrawals are assumed to be tax-free
# - This simplification is appropriate for:
#   - Tax-advantaged retirement accounts
#   - Jurisdictions without capital gains tax
#   - Long-term holdings exempt from taxation
#   - Theoretical baseline analysis
#
# ### Customization
# All parameters can be easily modified in this cell to test different scenarios.

# %%
# Portfolio allocation (must sum to 1.0)
PORTFOLIO_WEIGHTS = {
    'MSCI_WORLD': 0.60,  # 60% global stocks (Net Total Return)
    'BUND_10Y': 0.40,    # 40% German bonds
}

# Inflation to use
INFLATION_SERIES = 'HICP_EU'  # EU harmonized inflation

# Block bootstrap parameters
BLOCK_SIZE_MONTHS = 6  # Size of blocks in months (can be adjusted)

# Portfolio parameters
INITIAL_PORTFOLIO = 1000000  # Initial portfolio in EUR
ANNUAL_WITHDRAWAL_RATE = 0.04  # 4% initial SWR
RETIREMENT_YEARS = 30  # Retirement duration in years

# Tax assumption: NO capital gains tax applied on withdrawals
# This is an idealized scenario - in reality, withdrawals may be subject to taxation
# depending on the jurisdiction and account type (taxable vs tax-advantaged)
TAX_ON_WITHDRAWALS = False  # No tax applied

# Monte Carlo parameters
# With parallel processing via joblib, 100k simulations run much faster
# Recommended: 100000 for production (reduce for quick testing)
N_SIMULATIONS = 100000  # Number of simulations
SEED = 42  # For reproducibility

np.random.seed(SEED)

# Validate weights
total_weight = sum(PORTFOLIO_WEIGHTS.values())
assert abs(total_weight - 1.0) < 0.001, f"Portfolio weights must sum to 1.0, got {total_weight}"

print(f"Portfolio allocation:")
for asset, weight in PORTFOLIO_WEIGHTS.items():
    print(f"  {asset}: {weight:.1%}")
print(f"\nInflation series: {INFLATION_SERIES}")
print(f"Block size: {BLOCK_SIZE_MONTHS} months")
print(f"Number of simulations: {N_SIMULATIONS:,}")
print(f"Random seed: {SEED}")
print(f"\nTax on withdrawals: {'Yes' if TAX_ON_WITHDRAWALS else 'No (tax-free withdrawals)'}")
# Out:
# Portfolio allocation:
#   MSCI_WORLD: 60.0%
#   BUND_10Y: 40.0%
#
# Inflation series: HICP_EU
# Block size: 6 months
# Number of simulations: 100,000
# Random seed: 42
#
# Tax on withdrawals: No (tax-free withdrawals)

# %% [markdown]
# ---
#
# ## 6. Prepare Combined Dataset
#
# ### Data Merging Process
# 1. Merge asset returns on common dates (outer join)
# 2. Calculate weighted portfolio return: 0.6×MSCI_World + 0.4×Bund_10Y
# 3. Upsample monthly inflation to daily frequency
# 4. Forward-fill missing values
# 5. Drop any remaining NaN values
#
# ### Output
# - Combined dataset with daily portfolio returns and inflation
# - Summary statistics (annualized using 365 days/year)

# %%
# Merge selected assets
selected_assets = {name: assets_returns[name] for name in PORTFOLIO_WEIGHTS.keys()}
returns_df = merge_to_common_dates(selected_assets)

# Calculate portfolio daily return
returns_df['portfolio_return'] = 0.0
for asset, weight in PORTFOLIO_WEIGHTS.items():
    returns_df['portfolio_return'] += returns_df[asset] * weight

# Add inflation
inflation_df = inflation_returns[INFLATION_SERIES]
inflation_daily = upsample_inflation_to_daily(
    inflation_df,
    returns_df['date'].min(),
    returns_df['date'].max()
)

# Merge inflation
returns_df = pd.merge(returns_df, inflation_daily, on='date', how='left')

# Forward fill missing values
returns_df = returns_df.fillna(method='ffill').dropna()

print(f"Combined dataset:")
print(f"  Date range: {returns_df['date'].min()} to {returns_df['date'].max()}")
print(f"  Total days: {len(returns_df):,}")
print(f"\nFirst few rows:")
print(returns_df.head())

print(f"\nSummary statistics (annualized):")
print(f"  Portfolio return: {returns_df['portfolio_return'].mean() * 365:.2%} ± {returns_df['portfolio_return'].std() * np.sqrt(365):.2%}")
print(f"  Inflation: {returns_df['inflation'].mean() * 365:.2%}")
# Out:
# Combined dataset:
#   Date range: 2000-12-30 00:00:00 to 2025-12-05 00:00:00
#   Total days: 9,107
#
# First few rows:
#            date  MSCI_WORLD  BUND_10Y  portfolio_return  inflation
# 1247 2000-12-30    0.000000  0.000132          0.000053   0.000121
# 1248 2000-12-31    0.000000  0.000132          0.000053   0.000121
# 1249 2001-01-01    0.000000  0.000132          0.000053  -0.000150
# 1250 2001-01-02   -0.025090  0.000132         -0.015001  -0.000150
# 1251 2001-01-03    0.022885  0.000131          0.013783  -0.000150
#
# Summary statistics (annualized):
#   Portfolio return: 4.55% ± 9.87%
#   Inflation: 2.12%
# /tmp/ipykernel_1194/1581657729.py:22: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   returns_df = returns_df.fillna(method='ffill').dropna()

# %% [markdown]
# ---
#
# ## 7. Monte Carlo Simulation Functions
#
# ### Single Portfolio Simulation
# `simulate_portfolio_bootstrap()` simulates one retirement scenario:
# 1. **Bootstrap sample**: Generate 30 years of returns using block bootstrap
# 2. **Annual loop**: For each year:
#    - Compound daily returns to get annual return
#    - Compound daily inflation to get annual inflation
#    - Adjust withdrawal for inflation (after year 1)
#    - Withdraw at beginning of year
#    - Apply investment returns
# 3. **Portfolio tracking**: Record value each year
#
# ### Monte Carlo Runner
# `run_monte_carlo_bootstrap()` runs 100,000 independent simulations:
# - Each simulation uses different random block samples
# - Tracks all portfolio paths
# - Calculates success rate (portfolio > 0 after 30 years)

# %%
def simulate_portfolio_bootstrap(
    initial_portfolio: float,
    withdrawal_rate: float,
    years: int,
    returns_data: pd.DataFrame,
    block_size_months: int = 6,
    adjust_for_inflation: bool = True
) -> Tuple[np.ndarray, np.ndarray]:
    """
    Simulate portfolio evolution using block bootstrap.
    
    Note: This simulation assumes NO capital gains tax on withdrawals.
    The full withdrawal amount is taken from the portfolio without any
    tax deduction. For taxed scenarios, the withdrawal amount should be
    grossed up to account for the applicable tax rate.
    
    Returns:
        Tuple of (portfolio_values, withdrawal_amounts)
    """
    # Generate bootstrap sample
    bootstrap_data = block_bootstrap_sample(
        returns_data[['portfolio_return', 'inflation']],
        block_size_months=block_size_months,
        n_years=years
    )
    
    # Convert daily returns to yearly
    days_per_year = len(bootstrap_data) // years
    
    portfolio = np.zeros(years + 1)
    portfolio[0] = initial_portfolio
    
    withdrawals = np.zeros(years)
    annual_withdrawal = initial_portfolio * withdrawal_rate
    
    for year in range(years):
        # Get this year's daily returns
        start_idx = year * days_per_year
        end_idx = (year + 1) * days_per_year
        
        year_data = bootstrap_data.iloc[start_idx:end_idx]
        
        # Annual return (compound daily returns)
        annual_return = np.exp(year_data['portfolio_return'].sum()) - 1
        
        # Annual inflation (compound daily inflation)
        annual_inflation = np.exp(year_data['inflation'].sum()) - 1
        
        # Adjust withdrawal for inflation if requested
        if adjust_for_inflation and year > 0:
            annual_withdrawal *= (1 + annual_inflation)
        
        withdrawals[year] = annual_withdrawal
        
        # Withdrawal at the beginning of the year
        # NOTE: No capital gains tax is applied - the full withdrawal amount
        # is taken from the portfolio. In a taxed scenario, to receive the same
        # net amount, a higher gross withdrawal would be needed.
        portfolio[year + 1] = portfolio[year] - annual_withdrawal
        
        # Apply returns
        if portfolio[year + 1] > 0:
            portfolio[year + 1] *= (1 + annual_return)
        else:
            portfolio[year + 1] = 0  # Portfolio depleted
    
    return portfolio, withdrawals


def _run_single_simulation(
    sim_id: int,
    initial_portfolio: float,
    withdrawal_rate: float,
    years: int,
    returns_data: pd.DataFrame,
    block_size_months: int,
    adjust_for_inflation: bool
) -> Tuple[int, np.ndarray, bool]:
    """
    Wrapper function to run a single simulation.
    Returns: (simulation_id, portfolio_values, success)
    """
    portfolio, _ = simulate_portfolio_bootstrap(
        initial_portfolio,
        withdrawal_rate,
        years,
        returns_data,
        block_size_months,
        adjust_for_inflation
    )
    success = portfolio[-1] > 0
    return sim_id, portfolio, success


def run_monte_carlo_bootstrap(
    n_simulations: int,
    initial_portfolio: float,
    withdrawal_rate: float,
    years: int,
    returns_data: pd.DataFrame,
    block_size_months: int = 6,
    adjust_for_inflation: bool = True,
    n_jobs: int = -1
) -> Tuple[np.ndarray, float]:
    """
    Run Monte Carlo simulations using block bootstrap with parallel processing.
    
    Note: All simulations assume NO capital gains tax on withdrawals.
    
    Args:
        n_simulations: Number of simulations to run
        initial_portfolio: Initial portfolio value
        withdrawal_rate: Annual withdrawal rate
        years: Number of years to simulate
        returns_data: Historical returns data
        block_size_months: Block size for bootstrap
        adjust_for_inflation: Whether to adjust withdrawals for inflation
        n_jobs: Number of parallel jobs (-1 uses all available CPUs)
    
    Returns:
        Tuple of (all_portfolios, success_rate)
    """
    print(f"  Running {n_simulations:,} simulations using {n_jobs if n_jobs > 0 else 'all available'} CPU(s)...")
    
    # Run simulations in parallel
    results = Parallel(n_jobs=n_jobs, verbose=10)(
        delayed(_run_single_simulation)(
            i,
            initial_portfolio,
            withdrawal_rate,
            years,
            returns_data,
            block_size_months,
            adjust_for_inflation
        )
        for i in range(n_simulations)
    )
    
    # Collect results
    all_portfolios = np.zeros((n_simulations, years + 1))
    successes = 0
    
    for sim_id, portfolio, success in results:
        all_portfolios[sim_id] = portfolio
        if success:
            successes += 1
    
    success_rate = successes / n_simulations
    return all_portfolios, success_rate

# %% [markdown]
# ---
#
# ## 8. Run Base Simulation
#
# Executing 100,000 Monte Carlo simulations with 4% withdrawal rate.
#
# **Expected runtime**: 2-5 minutes depending on system

# %%
print(f"Running {N_SIMULATIONS:,} Monte Carlo simulations...")
portfolios, success_rate = run_monte_carlo_bootstrap(
    N_SIMULATIONS,
    INITIAL_PORTFOLIO,
    ANNUAL_WITHDRAWAL_RATE,
    RETIREMENT_YEARS,
    returns_df,
    BLOCK_SIZE_MONTHS
)

print(f"\nResults:")
print(f"  Success rate: {success_rate:.2%}")
print(f"  Median final value: €{np.median(portfolios[:, -1]):,.0f}")
print(f"  Mean final value: €{np.mean(portfolios[:, -1]):,.0f}")
# Out:
# Running 100,000 Monte Carlo simulations...
#   Running 100,000 simulations using all available CPU(s)...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.18689763255332123s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.05056595802307129s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 170 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0634315013885498s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done 224 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 308 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.07697486877441406s.) Setting batch_size=16.
# [Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 584 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 768 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1197512149810791s.) Setting batch_size=32.
# [Parallel(n_jobs=-1)]: Done 1168 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 1600 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 2464 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 3328 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 4256 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 5184 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 6176 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 7168 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 8224 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 9280 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 10400 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 11520 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 12704 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 13888 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done 15136 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 16384 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 17696 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 19008 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 20384 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 21760 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done 23200 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done 24640 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 26144 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done 27648 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 29216 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 30784 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done 32416 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done 34048 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done 35744 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done 37440 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=-1)]: Done 39200 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 40960 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done 42784 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done 44608 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 46496 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done 48384 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Done 50336 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done 52288 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done 54304 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done 56320 tasks      | elapsed:   13.5s
# [Parallel(n_jobs=-1)]: Done 58400 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=-1)]: Done 60480 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 62624 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=-1)]: Done 64768 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=-1)]: Done 66976 tasks      | elapsed:   16.1s
# [Parallel(n_jobs=-1)]: Done 69184 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=-1)]: Done 71456 tasks      | elapsed:   17.1s
# [Parallel(n_jobs=-1)]: Done 73728 tasks      | elapsed:   17.5s
# [Parallel(n_jobs=-1)]: Done 76064 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=-1)]: Done 78400 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=-1)]: Done 80800 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=-1)]: Done 83200 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=-1)]: Done 85664 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=-1)]: Done 88128 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=-1)]: Done 90656 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=-1)]: Done 93184 tasks      | elapsed:   22.0s
# [Parallel(n_jobs=-1)]: Done 95776 tasks      | elapsed:   22.6s
# [Parallel(n_jobs=-1)]: Done 98368 tasks      | elapsed:   23.2s
# Results:
#   Success rate: 69.35%
#   Median final value: €517,578
#   Mean final value: €964,391
# [Parallel(n_jobs=-1)]: Done 99753 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 100000 out of 100000 | elapsed:   23.6s finished

# %% [markdown]
# ---
#
# ## 9. Results Visualization
#
# ### Portfolio Evolution Chart
# Shows percentile bands across 30-year horizon:
# - **5th percentile**: Lower bound scenarios
# - **25th percentile**: Below-average outcomes
# - **50th percentile** (median): Central tendency
# - **75th percentile**: Above-average outcomes
# - **95th percentile**: Upper bound scenarios

# %%
# Portfolio evolution plot
fig, ax = plt.subplots(figsize=(14, 8))

years = np.arange(0, RETIREMENT_YEARS + 1)

# Percentiles
percentiles = [5, 25, 50, 75, 95]
colors = ['#d62728', '#ff7f0e', '#2ca02c', '#ff7f0e', '#d62728']

for i, p in enumerate(percentiles):
    values = np.percentile(portfolios, p, axis=0)
    ax.plot(years, values, label=f'{p}th percentile', 
            color=colors[i], linewidth=2 if p == 50 else 1.5)

# Zero line
ax.axhline(y=0, color='black', linestyle='--', linewidth=1, alpha=0.5)

ax.set_xlabel('Retirement years', fontsize=12)
ax.set_ylabel('Portfolio value (EUR)', fontsize=12)
ax.set_title(
    f'Monte Carlo Simulation with Block Bootstrap - {N_SIMULATIONS:,} simulations\n'
    f'SWR: {ANNUAL_WITHDRAWAL_RATE:.1%}, Block size: {BLOCK_SIZE_MONTHS} months, Success rate: {success_rate:.1%}',
    fontsize=14, fontweight='bold'
)
ax.legend(loc='best')
ax.grid(True, alpha=0.3)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'€{x/1000:.0f}k'))

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Final Portfolio Values Distribution
#
# Histogram showing distribution of portfolio values after 30 years:
# - Values **below zero** (left of red line): Failed scenarios
# - Values **above zero**: Successful scenarios
# - **Green line**: Median final value

# %%
# Final values distribution
fig, ax = plt.subplots(figsize=(12, 6))

final_values = portfolios[:, -1]
ax.hist(final_values, bins=50, edgecolor='black', alpha=0.7)
ax.axvline(x=0, color='red', linestyle='--', linewidth=2, label='Depletion')
ax.axvline(x=np.median(final_values), color='green', linestyle='--', 
           linewidth=2, label=f'Median: €{np.median(final_values):,.0f}')

ax.set_xlabel('Final portfolio value (EUR)', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
ax.set_title(
    f'Final values distribution after {RETIREMENT_YEARS} years',
    fontsize=14, fontweight='bold'
)
ax.legend()
ax.grid(True, alpha=0.3)
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'€{x/1000:.0f}k'))

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## 10. Sensitivity Analysis
#
# ### Withdrawal Rate Impact
# Testing withdrawal rates from 2% to 5% (in 0.1% increments) to understand:
# - How success rate changes with withdrawal rate
# - What is the maximum sustainable withdrawal rate?
# - Trade-off between spending and portfolio longevity
#
# **Expected runtime**: 15-30 minutes (10 different rates × 100,000 simulations each)

# %%
# Test different withdrawal rates
withdrawal_rates = np.arange(0.02, 0.051, 0.001)
success_rates = []

print("Testing different withdrawal rates...")
for wr in withdrawal_rates:
    print(f"\nWithdrawal rate: {wr:.1%}")
    _, sr = run_monte_carlo_bootstrap(
        N_SIMULATIONS,
        INITIAL_PORTFOLIO,
        wr,
        RETIREMENT_YEARS,
        returns_df,
        BLOCK_SIZE_MONTHS
    )
    success_rates.append(sr)
    print(f"  Success rate: {sr:.2%}")

# Create results DataFrame
df_wr = pd.DataFrame({
    'Withdrawal_Rate': withdrawal_rates,
    'Success_Rate': success_rates
})

print("\nSummary:")
print(df_wr)
# Out:
# Testing different withdrawal rates...
#
# Withdrawal rate: 2.0%
#   Running 100,000 simulations using all available CPU(s)...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0077784061431884766s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.04729413986206055s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.057738542556762695s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.07279205322265625s.) Setting batch_size=16.
# [Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 568 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.12891006469726562s.) Setting batch_size=32.
# [Parallel(n_jobs=-1)]: Done 752 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 1120 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 1488 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 2288 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 3088 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 3952 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 4816 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 5744 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 6672 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 7664 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 8656 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 9712 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 10768 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 11888 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 13008 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 14192 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done 15376 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 16624 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 17872 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done 19184 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done 20496 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done 21872 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=-1)]: Done 23248 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done 24688 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done 26128 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done 27632 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done 29136 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done 30704 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-1)]: Done 32272 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=-1)]: Done 33904 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done 35536 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-1)]: Done 37232 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-1)]: Done 38928 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done 40688 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done 42448 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done 44272 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=-1)]: Done 46096 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done 47984 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 49872 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done 51824 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done 53776 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=-1)]: Done 55792 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=-1)]: Done 57808 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done 59888 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-1)]: Done 61968 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 64112 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done 66256 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=-1)]: Done 68464 tasks      | elapsed:   15.9s
# [Parallel(n_jobs=-1)]: Done 70672 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=-1)]: Done 72944 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done 75216 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-1)]: Done 77552 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=-1)]: Done 79888 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=-1)]: Done 82288 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=-1)]: Done 84688 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=-1)]: Done 87152 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=-1)]: Done 89616 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=-1)]: Done 92144 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=-1)]: Done 94672 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=-1)]: Done 97264 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done 99329 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=-1)]: Done 99877 tasks      | elapsed:   23.0s
# [Parallel(n_jobs=-1)]: Done 100000 out of 100000 | elapsed:   23.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.008082866668701172s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.05159330368041992s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.05845046043395996s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:    0.1s
#   Success rate: 99.52%
#
# Withdrawal rate: 2.1%
#   Running 100,000 simulations using all available CPU(s)...
# [Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.07885122299194336s.) Setting batch_size=16.
# [Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 568 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1067969799041748s.) Setting batch_size=32.
# [Parallel(n_jobs=-1)]: Done 752 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 1120 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 1488 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 2288 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 3088 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 3952 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 4816 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 5744 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 6672 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 7664 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 8656 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 9712 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 10768 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 11888 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 13008 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 14192 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 15376 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done 16624 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 17872 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 19184 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 20496 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 21872 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 23248 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done 24688 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done 26128 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 27632 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done 29136 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 30704 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done 32272 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done 33904 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done 35536 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=-1)]: Done 37232 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done 38928 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=-1)]: Done 40688 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 42448 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 44272 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done 46096 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 47984 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done 49872 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 51824 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Done 53776 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done 55792 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=-1)]: Done 57808 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done 59888 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 61968 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 64112 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 66256 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done 68464 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Done 70672 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done 72944 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=-1)]: Done 75216 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 77552 tasks      | elapsed:   18.3s
# [Parallel(n_jobs=-1)]: Done 79888 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=-1)]: Done 82288 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=-1)]: Done 84688 tasks      | elapsed:   20.0s
# [Parallel(n_jobs=-1)]: Done 87152 tasks      | elapsed:   20.6s
# [Parallel(n_jobs=-1)]: Done 89616 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=-1)]: Done 92144 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=-1)]: Done 94672 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done 97264 tasks      | elapsed:   23.0s
# [Parallel(n_jobs=-1)]: Done 99360 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 99877 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=-1)]: Done 100000 out of 100000 | elapsed:   23.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.00833582878112793s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.048441171646118164s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.055005788803100586s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed:    0.2s
#   Success rate: 99.36%
#
# Withdrawal rate: 2.2%
#   Running 100,000 simulations using all available CPU(s)...
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.07073426246643066s.) Setting batch_size=16.
# [Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 568 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.13556289672851562s.) Setting batch_size=32.
# [Parallel(n_jobs=-1)]: Done 752 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 1120 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 1488 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 2288 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 3088 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 3952 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 4816 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 5744 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 6672 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 7664 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 8656 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 9712 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 10768 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 11888 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 13008 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 14192 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 15376 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done 16624 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 17872 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 19184 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 20496 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 21872 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 23248 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done 24688 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done 26128 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 27632 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done 29136 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 30704 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 32272 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done 33904 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done 35536 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done 37232 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done 38928 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done 40688 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 42448 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done 44272 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done 46096 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 47984 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done 49872 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 51824 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 53776 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done 55792 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done 57808 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=-1)]: Done 59888 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 61968 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 64112 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=-1)]: Done 66256 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done 68464 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=-1)]: Done 70672 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done 72944 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=-1)]: Done 75216 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 77552 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=-1)]: Done 79888 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=-1)]: Done 82288 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=-1)]: Done 84688 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=-1)]: Done 87152 tasks      | elapsed:   20.6s
# [Parallel(n_jobs=-1)]: Done 89616 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=-1)]: Done 92144 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=-1)]: Done 94672 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done 97264 tasks      | elapsed:   23.0s
# [Parallel(n_jobs=-1)]: Done 99298 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 99877 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=-1)]: Done 100000 out of 100000 | elapsed:   23.7s finished
#   Success rate: 99.08%
#
# Withdrawal rate: 2.3%
#   Running 100,000 simulations using all available CPU(s)...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.009565114974975586s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.04549098014831543s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.054882049560546875s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.07354235649108887s.) Setting batch_size=16.
# [Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 568 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.12885594367980957s.) Setting batch_size=32.
# [Parallel(n_jobs=-1)]: Done 752 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 1120 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 1488 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 2288 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 3088 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 3952 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 4816 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 5744 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 6672 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 7664 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 8656 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 9712 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 10768 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 11888 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 13008 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 14192 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 15376 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done 16624 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 17872 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 19184 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 20496 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 21872 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 23248 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done 24688 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done 26128 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 27632 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done 29136 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done 30704 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 32272 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done 33904 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done 35536 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done 37232 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done 38928 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done 40688 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-1)]: Done 42448 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done 44272 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done 46096 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 47984 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done 49872 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 51824 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 53776 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done 55792 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done 57808 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=-1)]: Done 59888 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 61968 tasks      | elapsed:   14.8s
# [Parallel(n_jobs=-1)]: Done 64112 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=-1)]: Done 66256 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=-1)]: Done 68464 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=-1)]: Done 70672 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done 72944 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-1)]: Done 75216 tasks      | elapsed:   18.0s
# [Parallel(n_jobs=-1)]: Done 77552 tasks      | elapsed:   18.5s
# [Parallel(n_jobs=-1)]: Done 79888 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=-1)]: Done 82288 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=-1)]: Done 84688 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=-1)]: Done 87152 tasks      | elapsed:   20.9s
# [Parallel(n_jobs=-1)]: Done 89616 tasks      | elapsed:   21.5s
# [Parallel(n_jobs=-1)]: Done 92144 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=-1)]: Done 94672 tasks      | elapsed:   22.8s
# [Parallel(n_jobs=-1)]: Done 97264 tasks      | elapsed:   23.4s
# [Parallel(n_jobs=-1)]: Done 99360 tasks      | elapsed:   23.9s
# [Parallel(n_jobs=-1)]: Done 99877 tasks      | elapsed:   24.0s
# [Parallel(n_jobs=-1)]: Done 100000 out of 100000 | elapsed:   24.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.010150671005249023s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.05099296569824219s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.05710268020629883s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:    0.1s
#   Success rate: 98.67%
#
# Withdrawal rate: 2.4%
#   Running 100,000 simulations using all available CPU(s)...
# [Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.08007073402404785s.) Setting batch_size=16.
# [Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 568 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.12856411933898926s.) Setting batch_size=32.
# [Parallel(n_jobs=-1)]: Done 752 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 1120 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 1488 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 2288 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 3088 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 3952 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 4816 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 5744 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 6672 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 7664 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 8656 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 9712 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 10768 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 11888 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 13008 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done 14192 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 15376 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 16624 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done 17872 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done 19184 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done 20496 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 21872 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done 23248 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done 24688 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 26128 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done 27632 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 29136 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 30704 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done 32272 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done 33904 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done 35536 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done 37232 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done 38928 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 40688 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done 42448 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done 44272 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 46096 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done 47984 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 49872 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 51824 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=-1)]: Done 53776 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done 55792 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-1)]: Done 57808 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 59888 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done 61968 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=-1)]: Done 64112 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=-1)]: Done 66256 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=-1)]: Done 68464 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done 70672 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-1)]: Done 72944 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=-1)]: Done 75216 tasks      | elapsed:   18.5s
# [Parallel(n_jobs=-1)]: Done 77552 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=-1)]: Done 79888 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=-1)]: Done 82288 tasks      | elapsed:   20.2s
# [Parallel(n_jobs=-1)]: Done 84688 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=-1)]: Done 87152 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=-1)]: Done 89616 tasks      | elapsed:   21.9s
# [Parallel(n_jobs=-1)]: Done 92144 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=-1)]: Done 94672 tasks      | elapsed:   23.1s
# [Parallel(n_jobs=-1)]: Done 97264 tasks      | elapsed:   23.7s
# [Parallel(n_jobs=-1)]: Done 99360 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=-1)]: Done 99877 tasks      | elapsed:   24.3s
# [Parallel(n_jobs=-1)]: Done 100000 out of 100000 | elapsed:   24.4s finished
#   Success rate: 98.18%
#
# Withdrawal rate: 2.5%
#   Running 100,000 simulations using all available CPU(s)...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.009444475173950195s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.04944038391113281s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.05785989761352539s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.07485103607177734s.) Setting batch_size=16.
# [Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 568 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.13781476020812988s.) Setting batch_size=32.
# [Parallel(n_jobs=-1)]: Done 752 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 1120 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 1488 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 2288 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 3088 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 3952 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 4816 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 5744 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 6672 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 7664 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 8656 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 9712 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 10768 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 11888 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 13008 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done 14192 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done 15376 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 16624 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done 17872 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done 19184 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 20496 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 21872 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done 23248 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done 24688 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 26128 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done 27632 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 29136 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done 30704 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done 32272 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done 33904 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=-1)]: Done 35536 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done 37232 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=-1)]: Done 38928 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 40688 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done 42448 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done 44272 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 46096 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done 47984 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 49872 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Done 51824 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done 53776 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=-1)]: Done 55792 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done 57808 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 59888 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=-1)]: Done 61968 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=-1)]: Done 64112 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done 66256 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Done 68464 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=-1)]: Done 70672 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-1)]: Done 72944 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 75216 tasks      | elapsed:   18.3s
# [Parallel(n_jobs=-1)]: Done 77552 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=-1)]: Done 79888 tasks      | elapsed:   19.4s
# [Parallel(n_jobs=-1)]: Done 82288 tasks      | elapsed:   19.9s
# [Parallel(n_jobs=-1)]: Done 84688 tasks      | elapsed:   20.5s
# [Parallel(n_jobs=-1)]: Done 87152 tasks      | elapsed:   21.1s
# [Parallel(n_jobs=-1)]: Done 89616 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=-1)]: Done 92144 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=-1)]: Done 94672 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=-1)]: Done 97264 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 99391 tasks      | elapsed:   24.0s
# [Parallel(n_jobs=-1)]: Done 99877 tasks      | elapsed:   24.0s
# [Parallel(n_jobs=-1)]: Done 100000 out of 100000 | elapsed:   24.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.007951498031616211s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.053746938705444336s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.05442309379577637s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:    0.1s
#   Success rate: 97.58%
#
# Withdrawal rate: 2.6%
#   Running 100,000 simulations using all available CPU(s)...
# [Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.07499861717224121s.) Setting batch_size=16.
# [Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 568 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.13063764572143555s.) Setting batch_size=32.
# [Parallel(n_jobs=-1)]: Done 752 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 1120 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 1488 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 2288 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 3088 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 3952 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 4816 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 5744 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 6672 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 7664 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 8656 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 9712 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 10768 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 11888 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 13008 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 14192 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 15376 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done 16624 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 17872 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 19184 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 20496 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 21872 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 23248 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done 24688 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done 26128 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 27632 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done 29136 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 30704 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 32272 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done 33904 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done 35536 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done 37232 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done 38928 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=-1)]: Done 40688 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 42448 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done 44272 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done 46096 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 47984 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done 49872 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 51824 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 53776 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done 55792 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done 57808 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done 59888 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 61968 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 64112 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 66256 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=-1)]: Done 68464 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=-1)]: Done 70672 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done 72944 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=-1)]: Done 75216 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 77552 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=-1)]: Done 79888 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=-1)]: Done 82288 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=-1)]: Done 84688 tasks      | elapsed:   20.0s
# [Parallel(n_jobs=-1)]: Done 87152 tasks      | elapsed:   20.6s
# [Parallel(n_jobs=-1)]: Done 89616 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=-1)]: Done 92144 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=-1)]: Done 94672 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done 97264 tasks      | elapsed:   23.0s
# [Parallel(n_jobs=-1)]: Done 99391 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 99877 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=-1)]: Done 100000 out of 100000 | elapsed:   23.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.008148193359375s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.04761672019958496s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.061322927474975586s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:    0.1s
#   Success rate: 96.95%
#
# Withdrawal rate: 2.7%
#   Running 100,000 simulations using all available CPU(s)...
# [Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.06724953651428223s.) Setting batch_size=16.
# [Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 568 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.13186383247375488s.) Setting batch_size=32.
# [Parallel(n_jobs=-1)]: Done 752 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 1120 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 1488 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 2288 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 3088 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 3952 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 4816 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 5744 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 6672 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 7664 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 8656 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 9712 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 10768 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 11888 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 13008 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 14192 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 15376 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done 16624 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 17872 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done 19184 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 20496 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 21872 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 23248 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done 24688 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done 26128 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 27632 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done 29136 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 30704 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 32272 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done 33904 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done 35536 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done 37232 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done 38928 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done 40688 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-1)]: Done 42448 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done 44272 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done 46096 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 47984 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done 49872 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 51824 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Done 53776 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=-1)]: Done 55792 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done 57808 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=-1)]: Done 59888 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 61968 tasks      | elapsed:   14.8s
# [Parallel(n_jobs=-1)]: Done 64112 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=-1)]: Done 66256 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=-1)]: Done 68464 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=-1)]: Done 70672 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done 72944 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=-1)]: Done 75216 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=-1)]: Done 77552 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=-1)]: Done 79888 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=-1)]: Done 82288 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=-1)]: Done 84688 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=-1)]: Done 87152 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=-1)]: Done 89616 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=-1)]: Done 92144 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=-1)]: Done 94672 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done 97264 tasks      | elapsed:   23.0s
# [Parallel(n_jobs=-1)]: Done 99360 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 99877 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=-1)]: Done 100000 out of 100000 | elapsed:   23.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.009371757507324219s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.05279207229614258s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.05867147445678711s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:    0.1s
#   Success rate: 96.08%
#
# Withdrawal rate: 2.8%
#   Running 100,000 simulations using all available CPU(s)...
# [Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.07623529434204102s.) Setting batch_size=16.
# [Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 568 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1385347843170166s.) Setting batch_size=32.
# [Parallel(n_jobs=-1)]: Done 752 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 1120 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 1488 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 2288 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 3088 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 3952 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 4816 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 5744 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 6672 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 7664 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 8656 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 9712 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 10768 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 11888 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 13008 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 14192 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 15376 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done 16624 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 17872 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done 19184 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 20496 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done 21872 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done 23248 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done 24688 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done 26128 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 27632 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done 29136 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done 30704 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 32272 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done 33904 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done 35536 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-1)]: Done 37232 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-1)]: Done 38928 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=-1)]: Done 40688 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 42448 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done 44272 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done 46096 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 47984 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done 49872 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 51824 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 53776 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done 55792 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done 57808 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done 59888 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 61968 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 64112 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 66256 tasks      | elapsed:   15.7s
# ...
# [Parallel(n_jobs=-1)]: Done 1120 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 1488 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 2288 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 3088 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 3952 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 4816 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 5744 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 6672 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 7664 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 8656 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 9712 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 10768 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 11888 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 13008 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done 14192 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 15376 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 16624 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done 17872 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done 19184 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 20496 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 21872 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done 23248 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done 24688 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 26128 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done 27632 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 29136 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 30704 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done 32272 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done 33904 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-1)]: Done 35536 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-1)]: Done 37232 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=-1)]: Done 38928 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 40688 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done 42448 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done 44272 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 46096 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done 47984 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-1)]: Done 49872 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 51824 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=-1)]: Done 53776 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done 55792 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-1)]: Done 57808 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 59888 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done 61968 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=-1)]: Done 64112 tasks      | elapsed:   15.9s
# [Parallel(n_jobs=-1)]: Done 66256 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=-1)]: Done 68464 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done 70672 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-1)]: Done 72944 tasks      | elapsed:   18.0s
# [Parallel(n_jobs=-1)]: Done 75216 tasks      | elapsed:   18.5s
# [Parallel(n_jobs=-1)]: Done 77552 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=-1)]: Done 79888 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=-1)]: Done 82288 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=-1)]: Done 84688 tasks      | elapsed:   20.9s
# [Parallel(n_jobs=-1)]: Done 87152 tasks      | elapsed:   21.5s
# [Parallel(n_jobs=-1)]: Done 89616 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=-1)]: Done 92144 tasks      | elapsed:   22.7s
# [Parallel(n_jobs=-1)]: Done 94672 tasks      | elapsed:   23.3s
# [Parallel(n_jobs=-1)]: Done 97264 tasks      | elapsed:   23.9s
# [Parallel(n_jobs=-1)]: Done 99267 tasks      | elapsed:   24.4s
# [Parallel(n_jobs=-1)]: Done 99877 tasks      | elapsed:   24.5s
# [Parallel(n_jobs=-1)]: Done 100000 out of 100000 | elapsed:   24.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.008504390716552734s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.04541587829589844s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.05728006362915039s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:    0.1s
#   Success rate: 44.45%
#
# Withdrawal rate: 4.9%
#   Running 100,000 simulations using all available CPU(s)...
# [Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.06936407089233398s.) Setting batch_size=16.
# [Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 568 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.12578082084655762s.) Setting batch_size=32.
# [Parallel(n_jobs=-1)]: Done 752 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 1120 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 1488 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 2288 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 3088 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 3952 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 4816 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 5744 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 6672 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 7664 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 8656 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 9712 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 10768 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 11888 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 13008 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done 14192 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 15376 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done 16624 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done 17872 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done 19184 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done 20496 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done 21872 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done 23248 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done 24688 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-1)]: Done 26128 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done 27632 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done 29136 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-1)]: Done 30704 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done 32272 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done 33904 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-1)]: Done 35536 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done 37232 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=-1)]: Done 38928 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 40688 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 42448 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done 44272 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 46096 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done 47984 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 49872 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done 51824 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done 53776 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=-1)]: Done 55792 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done 57808 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 59888 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 61968 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 64112 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done 66256 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=-1)]: Done 68464 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done 70672 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=-1)]: Done 72944 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=-1)]: Done 75216 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=-1)]: Done 77552 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=-1)]: Done 79888 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=-1)]: Done 82288 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=-1)]: Done 84688 tasks      | elapsed:   20.6s
# [Parallel(n_jobs=-1)]: Done 87152 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=-1)]: Done 89616 tasks      | elapsed:   21.9s
# [Parallel(n_jobs=-1)]: Done 92144 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=-1)]: Done 94672 tasks      | elapsed:   23.1s
# [Parallel(n_jobs=-1)]: Done 97264 tasks      | elapsed:   23.8s
# [Parallel(n_jobs=-1)]: Done 99267 tasks      | elapsed:   24.3s
# [Parallel(n_jobs=-1)]: Done 99877 tasks      | elapsed:   24.3s
# [Parallel(n_jobs=-1)]: Done 100000 out of 100000 | elapsed:   24.5s finished
#   Success rate: 40.98%
#
# Withdrawal rate: 5.0%
#   Running 100,000 simulations using all available CPU(s)...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.008700847625732422s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.04730558395385742s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.052890777587890625s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0635831356048584s.) Setting batch_size=16.
# [Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 568 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1356067657470703s.) Setting batch_size=32.
# [Parallel(n_jobs=-1)]: Done 752 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 1120 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 1488 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 2288 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 3088 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 3952 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 4816 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 5744 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 6672 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 7664 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 8656 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 9712 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 10768 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 11888 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 13008 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 14192 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 15376 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done 16624 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 17872 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 19184 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 20496 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 21872 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 23248 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done 24688 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done 26128 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done 27632 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done 29136 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done 30704 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done 32272 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done 33904 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-1)]: Done 35536 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done 37232 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=-1)]: Done 38928 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 40688 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done 42448 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=-1)]: Done 44272 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 46096 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done 47984 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-1)]: Done 49872 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 51824 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=-1)]: Done 53776 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done 55792 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-1)]: Done 57808 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 59888 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=-1)]: Done 61968 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=-1)]: Done 64112 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-1)]: Done 66256 tasks      | elapsed:   16.6s
# [Parallel(n_jobs=-1)]: Done 68464 tasks      | elapsed:   17.1s
# [Parallel(n_jobs=-1)]: Done 70672 tasks      | elapsed:   17.7s
# [Parallel(n_jobs=-1)]: Done 72944 tasks      | elapsed:   18.2s
# [Parallel(n_jobs=-1)]: Done 75216 tasks      | elapsed:   18.8s
# [Parallel(n_jobs=-1)]: Done 77552 tasks      | elapsed:   19.4s
# [Parallel(n_jobs=-1)]: Done 79888 tasks      | elapsed:   19.9s
# [Parallel(n_jobs=-1)]: Done 82288 tasks      | elapsed:   20.5s
# [Parallel(n_jobs=-1)]: Done 84688 tasks      | elapsed:   21.1s
# [Parallel(n_jobs=-1)]: Done 87152 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=-1)]: Done 89616 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=-1)]: Done 92144 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=-1)]: Done 94672 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 97264 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=-1)]: Done 99329 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=-1)]: Done 99877 tasks      | elapsed:   24.8s
#   Success rate: 38.42%
#
# Summary:
#     Withdrawal_Rate  Success_Rate
# 0             0.020       0.99521
# 1             0.021       0.99361
# 2             0.022       0.99082
# 3             0.023       0.98667
# 4             0.024       0.98177
# 5             0.025       0.97576
# 6             0.026       0.96951
# 7             0.027       0.96085
# 8             0.028       0.95099
# 9             0.029       0.93838
# 10            0.030       0.92474
# 11            0.031       0.90938
# 12            0.032       0.89239
# 13            0.033       0.87373
# 14            0.034       0.85288
# 15            0.035       0.82985
# 16            0.036       0.80664
# 17            0.037       0.78049
# 18            0.038       0.75269
# 19            0.039       0.72428
# 20            0.040       0.69270
# 21            0.041       0.66423
# 22            0.042       0.63260
# 23            0.043       0.59955
# 24            0.044       0.56850
# 25            0.045       0.53601
# 26            0.046       0.50563
# 27            0.047       0.47358
# 28            0.048       0.44454
# 29            0.049       0.40977
# 30            0.050       0.38425
# [Parallel(n_jobs=-1)]: Done 100000 out of 100000 | elapsed:   24.9s finished

# %% [markdown]
# ### Sensitivity Curve
#
# This chart shows the relationship between withdrawal rate and success probability:
# - **99% threshold** (green): Conservative safety level
# - **95% threshold** (orange): Moderate safety level
# - **90% threshold** (red): Acceptable risk level
# - Find the withdrawal rate that meets your risk tolerance

# %%
# Withdrawal rate sensitivity plot
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(withdrawal_rates * 100, np.array(success_rates) * 100, 
        marker='o', linewidth=2, markersize=6)
ax.axhline(y=99, color='green', linestyle='--', label='99% safety threshold')
ax.axhline(y=95, color='orange', linestyle='--', label='95% safety threshold')
ax.axhline(y=90, color='red', linestyle='--', label='90% safety threshold')

ax.set_xlabel('Annual withdrawal rate (%)', fontsize=12)
ax.set_ylabel('Success rate (%)', fontsize=12)
ax.set_title(
    f'Sensitivity Analysis - Withdrawal Rate vs Success Rate\n'
    f'({RETIREMENT_YEARS} years, {N_SIMULATIONS:,} simulations, {BLOCK_SIZE_MONTHS}-month blocks)',
    fontsize=14, fontweight='bold'
)
ax.legend()
ax.grid(True, alpha=0.3)
ax.set_ylim([0, 105])

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## 11. Detailed Statistical Analysis
#
# ### Year-by-Year Statistics
# For each year of retirement, showing:
# - **Median/Mean**: Central tendency
# - **P5/P25/P75/P95**: Distribution spread
# - **Failure_Prob**: Cumulative probability of depletion by that year

# %%
# Calculate statistics for each year
stats_df = pd.DataFrame({
    'Year': range(RETIREMENT_YEARS + 1),
    'Median': np.median(portfolios, axis=0),
    'Mean': np.mean(portfolios, axis=0),
    'P5': np.percentile(portfolios, 5, axis=0),
    'P25': np.percentile(portfolios, 25, axis=0),
    'P75': np.percentile(portfolios, 75, axis=0),
    'P95': np.percentile(portfolios, 95, axis=0),
    'Failure_Prob': np.sum(portfolios <= 0, axis=0) / N_SIMULATIONS
})

print("Portfolio evolution statistics (first 10 years):")
print(stats_df.head(11).to_string(index=False))

print("\nPortfolio evolution statistics (last 10 years):")
print(stats_df.tail(10).to_string(index=False))
# Out:
# Portfolio evolution statistics (first 10 years):
#  Year       Median         Mean             P5            P25          P75          P95  Failure_Prob
#     0 1.000000e+06 1.000000e+06 1000000.000000 1000000.000000 1.000000e+06 1.000000e+06           0.0
#     1 1.018964e+06 1.009141e+06  836377.233271  953402.201087 1.074264e+06 1.144006e+06           0.0
#     2 1.022590e+06 1.017771e+06  785652.682376  927543.596703 1.112035e+06 1.231346e+06           0.0
#     3 1.026651e+06 1.025958e+06  743925.955972  908617.742479 1.143316e+06 1.306774e+06           0.0
#     4 1.028298e+06 1.033841e+06  706990.364431  891102.907616 1.170357e+06 1.380210e+06           0.0
#     5 1.029865e+06 1.041353e+06  671168.625570  873715.266769 1.195652e+06 1.450212e+06           0.0
#     6 1.031259e+06 1.048424e+06  637980.569874  857841.408457 1.220535e+06 1.517218e+06           0.0
#     7 1.029507e+06 1.053887e+06  605973.204479  839386.905817 1.242451e+06 1.584895e+06           0.0
#     8 1.029818e+06 1.059484e+06  572181.119523  821079.940639 1.265035e+06 1.652936e+06           0.0
#     9 1.027250e+06 1.063939e+06  536227.300882  802183.187465 1.284391e+06 1.719619e+06           0.0
#    10 1.022875e+06 1.067888e+06  501428.861414  783377.439535 1.304682e+06 1.783867e+06           0.0
#
# Portfolio evolution statistics (last 10 years):
#  Year        Median         Mean  P5           P25          P75          P95  Failure_Prob
#    21 868754.027260 1.034974e+06 0.0 425424.141067 1.451451e+06 2.620319e+06       0.05712
#    22 840782.119038 1.026542e+06 0.0 377734.573972 1.459272e+06 2.708694e+06       0.07667
#    23 811243.852574 1.017637e+06 0.0 326152.707312 1.462036e+06 2.795427e+06       0.10025
#    24 778492.955500 1.008743e+06 0.0 270295.021552 1.463317e+06 2.885385e+06       0.12572
#    25 742261.406524 1.000510e+06 0.0 212089.845497 1.467529e+06 2.980205e+06       0.15303
#    26 705436.982522 9.914408e+05 0.0 149563.580426 1.469037e+06 3.073659e+06       0.18345
#    27 661472.781151 9.834520e+05 0.0  82197.247990 1.460882e+06 3.170577e+06       0.21416
#    28 617812.677981 9.767751e+05 0.0  11085.655460 1.458753e+06 3.276075e+06       0.24475
#    29 569417.942917 9.701839e+05 0.0      0.000000 1.451104e+06 3.383981e+06       0.27630
#    30 517577.844284 9.643913e+05 0.0      0.000000 1.439842e+06 3.496032e+06       0.30653

# %% [markdown]
# ### Failure Analysis
#
# For simulations that failed (portfolio depleted), analyze:
# - **When** did the portfolio run out?
# - Distribution of depletion years
# - Median/mean time to failure
#
# **Interpretation**:
# - Early failures (years 1-10): Very unlucky market sequence
# - Mid failures (years 10-20): Combination of poor returns and high withdrawals
# - Late failures (years 20-30): Nearly made it, close call

# %%
# Depletion year for failed simulations
depletion_years = []
for portfolio in portfolios:
    if portfolio[-1] <= 0:
        depletion_year = np.where(portfolio <= 0)[0]
        if len(depletion_year) > 0:
            depletion_years.append(depletion_year[0])

if depletion_years:
    fig, ax = plt.subplots(figsize=(12, 6))
    ax.hist(depletion_years, bins=RETIREMENT_YEARS, edgecolor='black', alpha=0.7)
    ax.set_xlabel('Depletion year', fontsize=12)
    ax.set_ylabel('Number of simulations', fontsize=12)
    ax.set_title(
        f'Portfolio depletion year distribution\n'
        f'({len(depletion_years)} failed simulations out of {N_SIMULATIONS})',
        fontsize=14, fontweight='bold'
    )
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    print(f"\nMedian depletion year: {np.median(depletion_years):.0f}")
    print(f"Mean depletion year: {np.mean(depletion_years):.1f}")
else:
    print("\nNo simulation resulted in portfolio depletion!")
# Out:
# Median depletion year: 26
# Mean depletion year: 25.0

# %% [markdown]
# ---
#
# ## 12. Summary and Conclusions
#
# Comprehensive summary of simulation results including:
# - Portfolio configuration
# - Historical data period used
# - Success rate and percentile outcomes
# - Failure statistics (if any)
#
# ### Key Takeaways
# 1. **Success Rate**: Indicates robustness of 4% withdrawal rate for this portfolio
# 2. **Percentiles**: Show range of possible outcomes
# 3. **Sensitivity**: Identifies maximum sustainable withdrawal rate
# 4. **Failures**: Understand downside risks and scenarios
#
# ### Important Caveat: No Tax Assumption
# This analysis assumes **no capital gains tax** is applied on withdrawals. In practice:
# - Italian investors face a 26% capital gains tax on financial gains
# - This would reduce the effective withdrawal rate or require higher gross withdrawals
# - Tax-advantaged accounts (where available) would more closely match these results

# %%
print("=" * 70)
print("MONTE CARLO SIMULATION SUMMARY (BLOCK BOOTSTRAP)")
print("=" * 70)
print(f"Simulation parameters:")
print(f"  - Initial portfolio: €{INITIAL_PORTFOLIO:,}")
print(f"  - Withdrawal rate: {ANNUAL_WITHDRAWAL_RATE:.1%}")
print(f"  - Retirement duration: {RETIREMENT_YEARS} years")
print(f"  - Number of simulations: {N_SIMULATIONS:,}")
print(f"  - Block size: {BLOCK_SIZE_MONTHS} months")
print(f"  - Capital gains tax: None (tax-free withdrawals)")
print(f"\nPortfolio composition:")
for asset, weight in PORTFOLIO_WEIGHTS.items():
    print(f"  - {asset}: {weight:.1%}")
print(f"\nInflation series: {INFLATION_SERIES}")
print(f"\nHistorical data period:")
print(f"  - From: {returns_df['date'].min()}")
print(f"  - To: {returns_df['date'].max()}")
print(f"  - Total days: {len(returns_df):,}")
print(f"\nResults:")
print(f"  - Success rate: {success_rate:.2%}")
print(f"  - Median final value: €{np.median(portfolios[:, -1]):,.0f}")
print(f"  - P5 final value: €{np.percentile(portfolios[:, -1], 5):,.0f}")
print(f"  - P95 final value: €{np.percentile(portfolios[:, -1], 95):,.0f}")
if depletion_years:
    print(f"  - Failed simulations: {len(depletion_years)} ({len(depletion_years)/N_SIMULATIONS:.1%})")
    print(f"  - Median depletion year: {np.median(depletion_years):.0f}")
print("=" * 70)
print("\n⚠️  NOTE: This simulation assumes NO capital gains tax on withdrawals.")
print("    In taxed scenarios, effective withdrawal rates would be lower.")
# Out:
# ======================================================================
# MONTE CARLO SIMULATION SUMMARY (BLOCK BOOTSTRAP)
# ======================================================================
# Simulation parameters:
#   - Initial portfolio: €1,000,000
#   - Withdrawal rate: 4.0%
#   - Retirement duration: 30 years
#   - Number of simulations: 100,000
#   - Block size: 6 months
#   - Capital gains tax: None (tax-free withdrawals)
#
# Portfolio composition:
#   - MSCI_WORLD: 60.0%
#   - BUND_10Y: 40.0%
#
# Inflation series: HICP_EU
#
# Historical data period:
#   - From: 2000-12-30 00:00:00
#   - To: 2025-12-05 00:00:00
#   - Total days: 9,107
#
# Results:
#   - Success rate: 69.35%
#   - Median final value: €517,578
#   - P5 final value: €0
#   - P95 final value: €3,496,032
#   - Failed simulations: 30653 (30.7%)
#   - Median depletion year: 26
# ======================================================================
#
# ⚠️  NOTE: This simulation assumes NO capital gains tax on withdrawals.
#     In taxed scenarios, effective withdrawal rates would be lower.
